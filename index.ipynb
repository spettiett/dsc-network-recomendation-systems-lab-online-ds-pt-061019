# %% [markdown]
# # Amazon Recommendation System - Lab
#
# ## Introduction
#
# Now that you've gotten an introduction to collaborative filtering and recommendation systems, it's time to put your skills to test and build a recommendation system for a real world dataset! For this lab, you'll be using a dataset regarding the book reviews on the Amazon marketplace. While the previous lesson focused on user-based recommendation systems, you'll apply a parallel process for an item-based recommendation system to recommend similar books at the bottom of the product page.
#
# ## Objectives
#
# In this lab you will:
#
# - Use graph-based similarity metrics to create a collaborative filtering recommender system

# %% [markdown]
# ## Load the Dataset

# %%
import pandas as pd
import networkx as nx
G = nx.Graph()

df = pd.read_csv('books_data.edgelist', names=['source', 'target', 'weight'], delimiter=' ')
df.head()
# Out:
#        source      target  weight
# 0  0827229534  0804215715     0.7
# 1  0827229534  156101074X     0.5
# 2  0827229534  0687023955     0.8
# 3  0827229534  0687074231     0.8
# 4  0827229534  082721619X     0.7

# %% [markdown]
# ## Load the Metadata
#
# Import the metadata available in the file `'books_meta.txt'` (note it is `'\t'` seperated).

# %%
df_meta = pd.read_csv('./books_meta.txt', sep='\t')
df_meta.head()
# Out:
#    Id        ASIN                                              Title  \
# 0   1  0827229534            Patterns of Preaching: A Sermon Sampler
# 1   2  0738700797                         Candlemas: Feast of Flames
# 2   3  0486287785   World War II Allied Fighter Planes Trading Cards
# 3   4  0842328327  Life Application Bible Commentary: 1 and 2 Tim...
# 4   5  1577943082    Prayers That Avail Much for Business: Executive
#
#                                           Categories Group  SalesRank  \
# 0  clergi sermon subject religion preach spiritu ...  Book     396585
# 1  subject witchcraft earth religion spiritu base...  Book     168596
# 2       general hobbi subject craft home garden book  Book    1270652
# 3  spiritu translat commentari christian book gui...  Book     631289
# 4  subject religion spiritu busi christian live w...  Book     455160
#
#    TotalReviews  AvgRating  DegreeCentrality  ClusteringCoeff
# 0             2        5.0                 8             0.80
# 1            12        4.5                 9             0.85
# 2             1        5.0                 0             0.00
# 3             1        4.0                 6             0.79
# 4             0        0.0                 4             1.00

# %% [markdown]
# ## Select Books to Test Your Recommender On
#
# Select a small subset of books that you are interested in generating recommendations for.

# %%
df_meta[df_meta['Title'].str.contains('Star Wars')]
# Out:
#             Id        ASIN                                              Title  \
# 976       1371  0553298046  Specter of the Past (Star Wars: The Hand of Th...
# 2283      3218  0553486519  A New Hope (Choose Your Own Star Wars Adventures)
# 2377      3318  0375800050  Learning Word Sounds: Kindergarten (Star Wars ...
# 2547      3562  0425168255  The Golden Globe (Star Wars: Junior Jedi Knights)
# 2708      3771  0553564927  The Last Command (Star Wars: The Thrawn Trilog...
# 3255      4559  0345435389                           Rogue Planet (Star Wars)
# 4099      5747  0345420675          The Essential Guide to Droids (Star Wars)
# 5042      7083  0345440749  Galactic Phrase Book & Travel Guide: Beeps, Bl...
# 7935     11312  0786928794  Coruscant and the Core Worlds (Star Wars Rolep...
# 9645     13831  0553472046  Star Wars: Showdown at Centerpoint (Corellian ...
# 388255           415        4.0                 4             0.87
# 388330            18        4.5                14             0.69
# 388561            86        4.0                12             0.62
# 388614             2        5.0                 1             0.00
# 388692             6        4.5                 3             0.58
# 389540             5        4.5                10             0.48
# 390518             5        4.5                 5             0.82
# 391068            15        4.5                 6             0.91
# 391248            13        4.5                 1             0.00
# 391423           174        3.5                 4             0.90
# 393219           195        3.5                 5             0.85
# 393263            21        4.0                 4             0.87
#
# [472 rows x 10 columns]

# %%
# Lets rexamine our fascination with Game of Thrones
myfav = df_meta[df_meta.Title.str.contains('Star Wars')][:10]
myfav
# Out:
#          Id        ASIN                                              Title  \
# 976    1371  0553298046  Specter of the Past (Star Wars: The Hand of Th...
# 2283   3218  0553486519  A New Hope (Choose Your Own Star Wars Adventures)
# 2377   3318  0375800050  Learning Word Sounds: Kindergarten (Star Wars ...
# 2547   3562  0425168255  The Golden Globe (Star Wars: Junior Jedi Knights)
# 2708   3771  0553564927  The Last Command (Star Wars: The Thrawn Trilog...
# 3255   4559  0345435389                           Rogue Planet (Star Wars)
# 4099   5747  0345420675          The Essential Guide to Droids (Star Wars)
# 5042   7083  0345440749  Galactic Phrase Book & Travel Guide: Beeps, Bl...
# 7935  11312  0786928794  Coruscant and the Core Worlds (Star Wars Rolep...
# 9645  13831  0553472046  Star Wars: Showdown at Centerpoint (Corellian ...
#
#                                              Categories Group  SalesRank  \
# 976   general subject media war seri fantasi book sc...  Book      18558
# 2283  literatur action book com media fiction genera...  Book     429785
# 2377  art general subject media nonfict episod war c...  Book     710560
# 2547  adventur general subject literatur magic actio...  Book     393200
# 2708  general subject media war trilog seri fantasi ...  Book       1949
# 3255  general subject media b author bear war z seri...  Book     152907
# 4099  nonfict general entertain subject media war se...  Book     104889
# 5042  general entertain subject media war critic ser...  Book     100113
# 7935  general entertain subject media war seri fanta...  Book      15656
# 9645  general subject media author macbrid roger war...  Book     599320
#
#       TotalReviews  AvgRating  DegreeCentrality  ClusteringCoeff
# 976            221        4.5                16             0.47
# 2283             2        4.5                 0             0.00
# 2377             1        4.0                 2             0.00
# 2547            18        4.0                 6             0.79
# 2708           136        4.5                14             0.39
# 3255           171        3.5                 4             0.90
# 4099            12        5.0                 7             0.83
# 5042             7        4.5                 4             0.43
# 7935             7        4.5                11             0.75
# 9645            25        3.5                 5             0.80

# %% [markdown]
# ## Generate Recommendations for a Few Books of Choice
#
# The `'books_data.edgelist'` has conveniently already calculated the distance between items for you. Given this preprocessed data, it's time to employ collaborative filtering to generate recommendations! Generate the top 10 recommendations for each book in the subset you chose. Be sure to print the book name that you are generating recommendations for as well as the name of the books being recommended.

# %%
# Well, got a couple or extraneous results in there, but perhaps good measure for comparion.
# What does our recommender return for these books?
rec_dict = {}
id_name_dict = dict(zip(df_meta.ASIN, df_meta.Title))
for row in myfav.index:
    book_id = myfav.ASIN[row]
    book_name = id_name_dict[book_id]
    most_similar = df[(df.source == book_id)
                      | (df.target == book_id)
                     ].sort_values(by='weight', ascending=False).head(10)
    most_similar['source_name'] = most_similar['source'].map(id_name_dict)
    most_similar['target_name'] = most_similar['target'].map(id_name_dict)
    recommendations = []
    for row in most_similar.index:
        if most_similar.source[row] == book_id:
            recommendations.append((most_similar.target_name[row], most_similar.weight[row]))
        else:
            recommendations.append((most_similar.source_name[row], most_similar.weight[row]))
    rec_dict[book_name] = recommendations
    print('Recommendations for:', book_name)
    for r in recommendations:
        print(r)
    print('\n\n')
# Out:
# Recommendations for: Specter of the Past (Star Wars: The Hand of Thrawn, Book One)
# ('The Last Command (Star Wars: The Thrawn Trilogy, Vol. 3)', 0.67)
# ('Dark Force Rising (Star Wars: The Thrawn Trilogy, Vol. 2)', 0.67)
# ('Heir to the Empire (Star Wars: The Thrawn Trilogy, Vol. 1)', 0.67)
# ('Heir to the Empire (Star Wars: The Thrawn Trilogy, Vol. 1)', 0.62)
# ('Dark Force Rising (Star Wars Vol. 2)', 0.62)
# ('Star Wars : Thrawn Omnibus', 0.62)
# ('Star Wars: Showdown at Centerpoint (Corellian Trilogy, No 3)', 0.59)
# ('The Corellian Trilogy Value Collection : Ambush at Corellia, Assault at Selonia, and Showdown at Centerpoint', 0.59)
# ('The Last Command (Star Wars: Thrawn Trilogy, Vol. 3)', 0.59)
# ('Star Wars: Champions of the Force/Dark Apprentice/Jedi Search', 0.56)
#
#
#
# Recommendations for: A New Hope (Choose Your Own Star Wars Adventures)
#
#
#
# Recommendations for: Learning Word Sounds: Kindergarten (Star Wars Fun-To-Learn Books)
# ('Writing Numbers 1 to 10: Preschool-Kindergarten (Star Wars Learning Fun Books - Write & Wipe)', 0.62)
# ('Writing Letters a to Z: Preschool-Kindergarten (Star Wars Fun-To-Learn Books)', 0.5)
#
#
#
# Recommendations for: The Golden Globe (Star Wars: Junior Jedi Knights)
# ('Jedi Bounty (Star Wars: Young Jedi Knights, Book 10)', 0.6)
# ("Vader's Fortress (Star Wars: Junior Jedi Knights (Paperback))", 0.57)
# ("Anakin's Quest (Star Wars: Junior Jedi Knights, Vol 4)", 0.55)
# ('Heirs of the Force (Star Wars: Young Jedi Knights, Book 1)', 0.55)
# ('Diverstiy alliance: young jedi knights #8 (Star Wars: Young Jedi Knights (Paperback))', 0.33)
# ("Kenobi's Blade (Star Wars: Junior Jedi Knights, Book 6)", 0.3)
#
#
#
# Recommendations for: The Last Command (Star Wars: The Thrawn Trilogy, Vol. 3)
# ('Vision of the Future (Star Wars : the Hand of Thrawn/Timothy Zahn, No. 2)', 0.88)
# ('Jedi Search (Star Wars: The Jedi Academy Trilogy, Vol. 1)', 0.76)
# ('Champions of the Force (Star Wars: The Jedi Academy Trilogy, Vol. 3)', 0.76)
# ('Dark Apprentice (Star Wars: The Jedi Academy Trilogy, Vol. 2)', 0.68)
# ('Specter of the Past (Star Wars: The Hand of Thrawn, Book One)', 0.67)
# ('Vision of the Future (Star Wars: The Hand of Thrawn, Book Two)', 0.67)
# ('The Truce at Bakura (Star Wars (Random House Paperback))', 0.67)
# ('Star Wars: Shadows of the Empire', 0.65)
# ('The Courtship of Princess Leia (Star Wars)', 0.65)
# ('Han Solo and the Lost Legacy (Classic Star Wars)', 0.62)
#
#
#
# Recommendations for: Rogue Planet (Star Wars)
# ('Star Wars, Episode I - The Phantom Menace', 0.65)
# ('Shadow Hunter (Star Wars: Darth Maul)', 0.62)
# ('Cloak of Deception (Star Wars)', 0.59)
# ('The Approaching Storm (Star Wars)', 0.57)
#
#
#
# Recommendations for: The Essential Guide to Droids (Star Wars)
# ('The Essential Guide to Weapons and Technology (Star Wars)', 0.84)
# ('The Essential Guide to Vehicles and Vessels (Star Wars)', 0.76)
# ('The Essential Guide to Alien Species (Star Wars)', 0.63)
# ('The Essential Chronology (Star Wars)', 0.63)
# ('The Wildlife of Star Wars: A Field Guide', 0.62)
# ('The Essential Guide to Planets and Moons (Star Wars)', 0.56)
# ('The New Essential Guide to Characters (Star Wars)', 0.54)
#
#
#
# Recommendations for: Galactic Phrase Book & Travel Guide: Beeps, Bleats, Boskas, and Other Common Intergalactic Verbiage (Star Wars)
# ('The Wildlife of Star Wars: A Field Guide', 0.94)
# ('The New Essential Guide to Characters (Star Wars)', 0.8)
# ('The Quotable Star Wars', 0.72)
# ('Star Wars: Diplomatic Corps Entrance Exam (Star Wars)', 0.48)
#
#
#
# Recommendations for: Coruscant and the Core Worlds (Star Wars Roleplaying Game)
# ('Ultimate Alien Anthology (Star Wars Roleplaying Game)', 1.0)
# ('Arms and Equipment Guide (Star Wars Roleplaying Game)', 1.0)
# ('Galactic Campaign Guide (Star Wars Roleplaying Game)', 1.0)
# ("Hero's Guide (Star Wars Roleplaying Game)", 1.0)
# ('Star Wars Adventure Game: The Invasion of Theed', 1.0)
# ('Starships of the Galaxy (Star Wars Roleplaying Game)', 1.0)
# ('Tempest Feud: An Adventure for 9th-Level Heroes (Star Wars Roleplaying Game)', 1.0)
# ('The New Jedi Order Sourcebook (Star Wars Roleplaying Game)', 0.78)
# ('Rebellion Era Sourcebook (Star Wars Roleplaying Game)', 0.78)
# ('Revised Core Rulebook (Star Wars Roleplaying Game)', 0.58)
#
#
#
# Recommendations for: Star Wars: Showdown at Centerpoint (Corellian Trilogy, No 3)
# ('Specter of the Past (Star Wars: The Hand of Thrawn, Book One)', 0.59)
# ('Shield of Lies (Star Wars: The Black Fleet Crisis, Book 2)', 0.55)
# ('The New Rebellion (Star Wars)', 0.5)
# ('Before the Storm (Star Wars: The Black Fleet Crisis, Book 1)', 0.5)
# ("Tyrant's Test (Star Wars: The Black Fleet Crisis, Book 3)", 0.5)

# %% [markdown]
# ## Summary
#
# Well done! In this lab, you effectively created a recommendation system for a real world dataset!
